# %% [markdown]
# **flowchart**
# <p>High-level flow chart showing the system architecture of k-means clustering  prototype, the diagram shows the flow of data from the input through to the output then visualised results.<p/>
#
# <p>The prototype will use a customer dataset with more than 1000 records, each row is unique and the columns of each customer will have information such as age , item, annual income etc. The data i will be using will be stored as a CSV file.It is important before doing clustering the file needs to be transformed which means the data needs to be sorted , cleaned and missing values need to be handled.This is done to improve the quality of the data

# %% [markdown]
# ![aicluster-Page-2.jpg](data:image/jpeg;base64,...)
#
# ---
#
#
#
# ```
#
# ```

# %% [markdown]
# **Description of input data and pre processing for clustering implementation**
# <h3>Type of input data and data source</h3>
# <p>The clustering implementation will require multivariate data like a CSV file, where each customer will have their own dedicated row and in the columns will represent an attribute, the data set will contain numerical and catagorical variables that will give information on customer behaviour. Using CSV files like this in clusters is commonly used and is best suited for unsupervised learning techniques.Data will be sourced from public data sites, i will plan to get my data set from kaggle, ensuring its tailored to focusing on customer segmenttion and contains both numerical and catagorical dat, it must have CustomerID , age etc. And convert it into a CSV file to work with, by using a public customer data set this also avoids any ethical concerns as its public and doesnt violate any privacy concerns.The format of the data as i had stated previously i will be using a CSV(Comma separated values) file </p>
#
# <h3>Data preparation and pre-processing</h3>
# <p>I will have to do pre-processing before implmenting the cluster as i need to clen the data make sure that there are no missing values and the technique will return ccurate and meaningful results.</p>
# <p>I need to handle missing values, this is missing or null vaules, these values needs to be removed or replaced. Cluster lgorithms cannot deal with imcomplete data and this will interfere with the return. Feature selection needs to be done and this is where i only include the data i want to be  included to reduce noise and outliers. Encoding catagorical variable clustering works with numerical data so catagorical data such as gender or demographics need to translated into a binry code to represent the options and finally we can handle missing values and outlier detection.</p>
# <h3>Advantages of pre-processing</h3>
# <p>Bu pre-processing data for the clustering slgorithm this helps with identifying customer segments and measure similarities between customers and this will support marketing decisions in the business such as making targeting advertisements and campaigns and personalised offers to customers which will increase the interest in the business and maintain loyalty.</p>

# %% [markdown]
# <h2> Software testing and evaluation</h2>
# <p>This algorithm is expected to take a data set and group customers according to their characteristics and display clusters on the graph in a coloured format. </p>
#
# <p1>If the algoirthm was implemented correctly it should have output a graph with different colours that represent different customer segmentations, i had coded that there will be 5 different clusters.The customers with similar income and spending scores should appear in the same cluster , and clusters should be distinct and not overlapping over eachother and if i was to input the dataset again it should display the same results.</p1>
#
# <p2>clustering is an unsupervised technique and there is no ground truth label to compare results with each output is unique and tailored specifically to the data set that is used, the only way we can evaluate results is by looking at the visual output which would be the way the clusters are formed and consistency of the different values of k. WCSS (Within-cluster sun of squares) this is the sum of squared distances between each data point and joined to cluster centroid. a lower wcss indicates more compact and consistent clusters.The selection of optimal k which is 5 was selected as it provides a balence and a reasonabloe amount of clusters.</p2>
# <p3>The comarison of expected results vs the actual results. The expected resuts should be that customers are grouped according to their income and spend score and have a good separation, a distinct separation between segments. In my actual results i have alot of overlapping and i dont think its very distinct however this could be because of the data set that i have used has caused this. the different colours/clusters are gruped towards a certain area of the graph however its not very close and its allm very spread out.Howver we are still able to see the high spending vs the low spending customer groups.However its said that overlapping is normal is real world consumer data where customer behaviours do not always fall into distinct catagories. </p3>
# <p4>In conclusion i believe that the algorithm did what it was programmed to do even if i was to input another dataset. The visual inspection of the cluster i believe was implemented correctly and i think the disorganisation is to blame because of the data set that i have used.</p4>
